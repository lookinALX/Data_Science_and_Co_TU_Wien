# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df_datasets = pd.read_csv('datasets.csv', delimiter=';', quotechar='"')
df_datasets.head()
# Out:
#         Dataset Number of citations (Google Scholar since 2020)  \
# 0      AudioSet                                         5580,00
# 1     AudioCaps                                          761,00
# 2      AVSpeech                                          730,00
# 3  UrbanSound8K                                         1330,00
# 4        ESC-50                                         1820,00
#
#   Number of usage (Papers with code since 2020) Music/Speech/Sounds  \
# 0                                        581,00              Sounds
# 1                                        218,00              Sounds
# 2                                         36,00              Speech
# 3                                         99,00              Sounds
# 4                                        298,00              Sounds
#
#                                                 Link  \
# 0              https://research.google.com/audioset/
# 1                       https://audiocaps.github.io/
# 2               https://looking-to-listen.github.io/
# 3  https://urbansounddataset.weebly.com/urbansoun...
# 4              https://github.com/karolpiczak/ESC-50
#
#                                           Paper Link  \
# 0       https://ieeexplore.ieee.org/document/7952261
# 1                 https://aclanthology.org/N19-1011/
# 2                   https://arxiv.org/abs/1804.03619
# 3  https://www.justinsalamon.com/uploads/4/3/9/4/...
# 4     https://dl.acm.org/doi/10.1145/2733373.2806390
#
#   Model in Paper (Paper Link if Link Model Paper == null)  \
# 0                                                CNN
# 1                                       VGGish-LSTM
# 2                                                NaN
# 3                                                SVM
# 4                                                NaN
#
#   Score or best score in Paper              Metrics in Paper  Year  ...  \
# 0                       31,400  mAP (mean Average Precision)  2017  ...
# 1                    19,3;50,9                  METEOR;CIDEr  2019  ...
# 2                          NaN                           NaN  2018  ...
# 3                       70,000                      Accuracy  2014  ...
# 4                          NaN                           NaN  2015  ...
#
#   Size (Hours)  Contents based on              Source Language  \
# 0        58000  short video clips             Youtube  English
# 1       108,60        audio clips    AudioSet subset   English
# 2         4700  short video clips  Youtube; TED Talks  English
# 3        27607        audio clips       Freesound.org      NaN
# 4        28157        audio clips       Freesound.org      NaN
#
#   Number of Benchmarks (Audio Classification or Recognition Papers with Code different models)  \
# 0                                              53,00
# 1                                                NaN
# 2                                                NaN
# 3                                               4,00
# 4                                              50,00
#
#   Best Scoure Best Model related to scoure     Metrics related to scoure  \
# 0       55,80                     OmniVec2  mAP (mean Average Precision)
# 1         NaN                          NaN                           NaN
# 2         NaN                          NaN                           NaN
# 3       98,05                         FACE                      Accuracy
# 4       99,10                     OmniVec2                      Accuracy
#
#                                     Link Model Paper Comment
# 0  https://paperswithcode.com/paper/omnivec2-a-no...     NaN
# 1                                                NaN     NaN
# 2                                                NaN     NaN
# 3                 https://arxiv.org/pdf/2303.03666v1     NaN
# 4  https://paperswithcode.com/paper/omnivec2-a-no...     NaN
#
# [5 rows x 23 columns]

# %%
print("Basic Info:\n")
print(df_datasets.info())
# Out:
# Basic Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 23 columns):
#  #   Column                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                        --------------  -----
#  0   Dataset                                                                                       50 non-null     object
#  1   Number of citations (Google Scholar since 2020)                                               49 non-null     object
#  2   Number of usage (Papers with code since 2020)                                                 50 non-null     object
#  3   Music/Speech/Sounds                                                                           50 non-null     object
#  4   Link                                                                                          50 non-null     object
#  5   Paper Link                                                                                    48 non-null     object
#  6   Model in Paper (Paper Link if Link Model Paper == null)                                       30 non-null     object
#  7   Score or best score in Paper                                                                  31 non-null     object
#  8   Metrics in Paper                                                                              31 non-null     object
#  9   Year                                                                                          50 non-null     int64
#  10  Author                                                                                        32 non-null     object
#  11  Original Use Case                                                                             50 non-null     object
#  12  Category Source                                                                               50 non-null     object
#  13  Size (Hours)                                                                                  46 non-null     object
#  14  Contents based on                                                                             50 non-null     object
#  15  Source                                                                                        48 non-null     object
#  16  Language                                                                                      22 non-null     object
#  17  Number of Benchmarks (Audio Classification or Recognition Papers with Code different models)  26 non-null     object
#  18  Best Scoure                                                                                   29 non-null     object
#  19  Best Model related to scoure                                                                  29 non-null     object
#  20  Metrics related to scoure                                                                     29 non-null     object
#  21  Link Model Paper                                                                              31 non-null     object
#  22  Comment                                                                                       16 non-null     object
# dtypes: int64(1), object(22)
# memory usage: 9.1+ KB
# None

# %%
numeric_columns = ['Number of citations (Google Scholar since 2020)', 'Number of usage (Papers with code since 2020)', 
                   'Score or best score in Paper', 'Size (Hours)', 
                   'Number of Benchmarks (Audio Classification or Recognition Papers with Code different models)',
                   'Best Scoure']

df_datasets[numeric_columns] = df_datasets[numeric_columns].replace({',':'.'}, regex=True)
df_datasets[numeric_columns] = df_datasets[numeric_columns].apply(pd.to_numeric, errors='coerce')

# %%
# top 5 most cited datasets
most_cited = df_datasets.nlargest(5, 'Number of citations (Google Scholar since 2020)')
print("\nTop 5 Most Cited Datasets:\n")
print(most_cited[['Dataset', 'Number of citations (Google Scholar since 2020)']])

# top 5 most used datasets
most_used = df_datasets.nlargest(5, 'Number of usage (Papers with code since 2020)')
print("\nTop 5 Most Used Datasets:\n")
print(most_used[['Dataset', 'Number of usage (Papers with code since 2020)']])

# datasets by category
category_counts = df_datasets['Music/Speech/Sounds'].value_counts()
print("\nDatasets by Category:\n")
print(category_counts)
# Out:
# Top 5 Most Cited Datasets:
#
#                Dataset  Number of citations (Google Scholar since 2020)
# 15   TUT Sound Events                                           16800.0
# 29                MELD                                          11900.0
# 5          LibriSpeech                                           8850.0
# 13  Speech Commands V2                                           8260.0
# 46               Wham!                                           7660.0
#
# Top 5 Most Used Datasets:
#
#         Dataset  Number of usage (Papers with code since 2020)
# 5   LibriSpeech                                         1891.0
# 0      AudioSet                                          581.0
# 39      IEMOCAP                                          558.0
# 10     VoxCeleb                                          490.0
# 8   CommonVoice                                          363.0
#
# Datasets by Category:
#
# Music/Speech/Sounds
# Sounds          24
# Speech          18
# Music            7
# Music; Sound     1
# Name: count, dtype: int64

# %%
category_counts = category_counts.drop("Music; Sound")
category_counts["Sounds"] += 1
category_counts["Music"] += 1

expanded_rows = []
for _, row in df_datasets.iterrows():
    if row['Music/Speech/Sounds'] == 'Music; Sound':
        row_music = row.copy()
        row_music['Music/Speech/Sounds'] = 'Music'
        expanded_rows.append(row_music)

        row_sounds = row.copy()
        row_sounds['Music/Speech/Sounds'] = 'Sounds'
        expanded_rows.append(row_sounds)
    else:
        expanded_rows.append(row)

df_datasets = pd.DataFrame(expanded_rows)

# %%
plt.figure(figsize=(12, 6))
plt.bar(category_counts.index, category_counts.values, color=sns.color_palette('viridis', len(category_counts)))
plt.title('Distribution of Datasets by Content Category')
plt.xlabel('Content')
plt.ylabel('Number of Datasets')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(12, 6))
sns.scatterplot(data=df_datasets, 
                x='Number of citations (Google Scholar since 2020)', 
                y='Number of usage (Papers with code since 2020)', 
                hue='Music/Speech/Sounds', 
                palette='viridis', 
                alpha=0.7)

for i, row in df_datasets.iterrows():
    if row['Number of citations (Google Scholar since 2020)'] > 1800:
        plt.text(
            row['Number of citations (Google Scholar since 2020)'], 
            row['Number of usage (Papers with code since 2020)'], 
            str(row['Dataset']), 
            fontsize=8, 
            alpha=0.7
        )

plt.title('Citations vs. Usage by Dataset')
plt.xlabel('Number of Citations')
plt.ylabel('Number of Usage')
plt.legend(title='Content Category')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df_datasets, 
                x='Number of Benchmarks (Audio Classification or Recognition Papers with Code different models)', 
                y='Number of usage (Papers with code since 2020)',  
                alpha=0.7)

for i, row in df_datasets.iterrows():
    if (row['Number of usage (Papers with code since 2020)'] > 100 or 
        row['Number of Benchmarks (Audio Classification or Recognition Papers with Code different models)'] > 15):
        plt.text(
            row['Number of Benchmarks (Audio Classification or Recognition Papers with Code different models)'], 
            row['Number of usage (Papers with code since 2020)'], 
            str(row['Dataset']), 
            fontsize=8, 
            alpha=0.7
        )

plt.title('Number of Benchmarks vs. Usage by Dataset')
plt.xlabel('Number of Benchmarks')
plt.ylabel('Number of Usage')
plt.grid(True)
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
sources_counts = df_datasets['Source'].value_counts()

plt.figure(figsize=(12, 6))
plt.bar(sources_counts.index, sources_counts.values, color=sns.color_palette('viridis', len(sources_counts)))
plt.title('Distribution of Datasets Sources')
plt.xlabel('Source')
plt.ylabel('Number of Datasets')
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

sources_category_counts = df_datasets['Category Source'].value_counts()

plt.figure(figsize=(12, 6))
plt.bar(sources_category_counts.index, sources_category_counts.values, color=sns.color_palette('viridis', len(sources_category_counts)))
plt.title('Distribution of Datasets Sources')
plt.xlabel('Category Source')
plt.ylabel('Number of Datasets')
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
df_datasets_original_classification = df_datasets[df_datasets['Original Use Case'].str.contains('classification', na=False)]
df_datasets_original_classification.head()
# Out:
#                              Dataset  \
# 3                       UrbanSound8K
# 4                             ESC-50
# 7                             FSD50K
# 11  ICBHI Respiratory Sound Database
# 12   SHD (Spiking Heidelberg Digits)
#
#     Number of citations (Google Scholar since 2020)  \
# 3                                            1330.0
# 4                                            1820.0
# 7                                             625.0
# 11                                            679.0
# 12                                            209.0
#
#     Number of usage (Papers with code since 2020) Music/Speech/Sounds  \
# 3                                            99.0              Sounds
# 4                                           298.0              Sounds
# 7                                           139.0              Sounds
# 11                                           12.0              Sounds
# 12                                           16.0              Speech
#
#                                                  Link  \
# 3   https://urbansounddataset.weebly.com/urbansoun...
# 4               https://github.com/karolpiczak/ESC-50
# 7                  https://zenodo.org/records/4060432
# 11  https://bhichallenge.med.auth.gr/ICBHI_2017_Ch...
# 12  https://zenkelab.org/resources/spiking-heidelb...
#
#                                            Paper Link  \
# 3   https://www.justinsalamon.com/uploads/4/3/9/4/...
# 4      https://dl.acm.org/doi/10.1145/2733373.2806390
# 7   https://dl.acm.org/doi/10.1109/TASLP.2021.3133208
# 11                                                NaN
# 12  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
#
#    Model in Paper (Paper Link if Link Model Paper == null)  \
# 3                                                 SVM
# 4                                                 NaN
# 7                                                 NaN
# 11                                                NaN
# 12                                                CNN
#
#     Score or best score in Paper Metrics in Paper  Year  ... Size (Hours)  \
# 3                           70.0         Accuracy  2014  ...      27607.0
# 4                            NaN              NaN  2015  ...      28157.0
# 7                            NaN              NaN  2020  ...        145.0
# 11                           NaN              NaN  2016  ...      45782.0
# 12                          92.4         Accuracy  2022  ...          NaN
#
#     Contents based on                   Source  Language  \
# 3         audio clips            Freesound.org       NaN
# 4         audio clips            Freesound.org       NaN
# 7   short video clips  Freesound.org ;AudioSet   English
# 11        audio clips                 Recoding       NaN
# 12        audio clips                 Recoding   English
#
#    Number of Benchmarks (Audio Classification or Recognition Papers with Code different models)  \
# 3                                                 4.0
# 4                                                50.0
# 7                                                 9.0
# 11                                               21.0
# 12                                               11.0
#
#    Best Scoure Best Model related to scoure     Metrics related to scoure  \
# 3        98.05                         FACE                      Accuracy
# 4        99.10                     OmniVec2                      Accuracy
# 7        69.70                    ONE-PEACE  mAP (mean Average Precision)
# 11       63.54                          BTS                   ICBHI Score
# 12       95.90                    Event-SSM                      Accuracy
#
#                                      Link Model Paper Comment
# 3                  https://arxiv.org/pdf/2303.03666v1     NaN
# 4   https://paperswithcode.com/paper/omnivec2-a-no...     NaN
# 7                  https://arxiv.org/pdf/2305.11172v1     NaN
# 11                 https://arxiv.org/pdf/2406.06786v2     NaN
# 12                 https://arxiv.org/pdf/2404.18508v3     NaN
#
# [5 rows x 23 columns]

# %%
# top 5 most cited datasets
most_cited = df_datasets_original_classification.nlargest(5, 'Number of citations (Google Scholar since 2020)')
print("\nTop 5 Most Cited Datasets:\n")
print(most_cited[['Dataset', 'Number of citations (Google Scholar since 2020)']])

# top 5 most used datasets
most_used = df_datasets_original_classification.nlargest(5, 'Number of usage (Papers with code since 2020)')
print("\nTop 5 Most Used Datasets:\n")
print(most_used[['Dataset', 'Number of usage (Papers with code since 2020)']])

# datasets by category
category_counts = df_datasets_original_classification['Music/Speech/Sounds'].value_counts()
print("\nDatasets by Category:\n")
print(category_counts)
# Out:
# Top 5 Most Cited Datasets:
#
#               Dataset  Number of citations (Google Scholar since 2020)
# 15  TUT Sound Events                                           16800.0
# 38             DiCOVA                                           1990.0
# 4              ESC-50                                           1820.0
# 42    Coswara Dataset                                           1560.0
# 3        UrbanSound8K                                           1330.0
#
# Top 5 Most Used Datasets:
#
#                             Dataset  \
# 4                            ESC-50
# 22  EPIC-SOUNDS (EPIC-KITCHENS-100)
# 7                            FSD50K
# 3                      UrbanSound8K
# 45                         CoughVid
#
#     Number of usage (Papers with code since 2020)
# 4                                           298.0
# 22                                          148.0
# 7                                           139.0
# 3                                            99.0
# 45                                           27.0
#
# Datasets by Category:
#
# Music/Speech/Sounds
# Sounds    14
# Speech     2
# Music      1
# Name: count, dtype: int64
